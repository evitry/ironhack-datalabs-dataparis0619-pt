# %%
import pandas as pd

# %%
data = pd.read_csv('donnes trimestrielles.csv')
data.head()
# Out:
#    Unnamed: 0        date  \
# 0           1  2000-01-01
# 1           2  2000-04-01
# 2           3  2000-07-01
# 3           4  2000-10-01
# 4           5  2001-01-01
#
#   prix_courant en MD: Valeurs ajoutees du secteur Activites de services marchands  \
# 0                                            2747,78
# 1                                            2764,66
# 2                                            2813,15
# 3                                            2884,21
# 4                                            2998,82
#
#   prix_courant en MD: Valeurs ajoutees du secteur Activites marchands  \
# 0                                            5179,99
# 1                                            5282,33
# 2                                            5455,76
# 3                                            5612,42
# 4                                             5716,6
#
#   prix_courant en MD: Valeurs ajoutees du secteur Agriculture et peche  \
# ...
